# %% [markdown]
# # Lab - CarPark Vacancy
# Reference: Dataset was extracted from one of the KlangValley shopping mall (updated to Nov 2018)
#
# Exercise:
# 1. Predict the carpark vacant status in Zone A.

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import shutil
# Out:
# C:\Anaconda\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ## Reading dataset

# %%
df_sep = pd.read_csv("./data/carpark/2018-09/vacantBays_2018-9.csv")
print('Sep dataset: {}'.format(df_sep.shape))

df_oct = pd.read_csv("./data/carpark/2018-10/vacantBays_2018-10.csv")
#df_oct.dtypes
print('Oct dataset: {}'.format(df_oct.shape))

df_nov = pd.read_csv("./data/carpark/2018-11/vacantBays_2018-11.csv")
print('Nov dataset: {}'.format(df_nov.shape))

df = df_sep.append(df_oct.append(df_nov))
print('Sep - Oct dataset: {}'.format(df.shape))
# Out:
# Sep dataset: (1051, 9)
# Oct dataset: (2969, 9)
# Nov dataset: (2871, 9)
# Sep - Oct dataset: (6891, 9)

# %% [markdown]
# ## Cleanup & prepare data metadata

# %%
#Cleanup numbers

cleanup_nums = {"A": {"FULL": 0},
                "B": {"FULL": 0},
                "C": {"FULL": 0},
                "G": {"FULL": 0},
                "H": {"FULL": 0},
                "P": {"FULL": 0},
                "U": {"FULL": 0},
               }

df.replace(cleanup_nums, inplace=True)
df.dropna(subset=['A','B','C','G','H','P','U'])
print(df.shape)
# Out:
# (6891, 9)

# %%
# Convert to datetime

df['A'] = df['A'].astype(np.float64)
df['B'] = df['B'].astype(np.float64)
df['C'] = df['C'].astype(np.float64)
df['G'] = df['G'].astype(np.float64)
df['H'] = df['H'].astype(np.float64)
df['P'] = df['P'].astype(np.float64)
df['U'] = df['U'].astype(np.float64)
df['DateTime'] =  pd.to_datetime(df['DateTime'])
df.dtypes
# Out:
# DateTime      datetime64[ns]
# IsoWeekday             int64
# A                    float64
# B                    float64
# C                    float64
# G                    float64
# H                    float64
# P                    float64
# U                    float64
# dtype: object

# %%
# Extract Hour and Minute
df['Hour'] = df.DateTime.apply(lambda x: x.hour)
df['Minute'] = df.DateTime.apply(lambda x: x.minute)
df.head()
# Out:
#                     DateTime  IsoWeekday      A       B      C       G  \
# 0 2018-09-20 01:32:30.850890           4  770.0  2592.0  875.0  1410.0
# 1 2018-09-20 01:39:01.932373           4  773.0  2590.0  876.0  1415.0
# 2 2018-09-20 01:39:40.024931           4  773.0  2591.0  876.0  1414.0
# 3 2018-09-20 01:39:52.258908           4  773.0  2591.0  876.0  1415.0
# 4 2018-09-20 01:40:49.225890           4  773.0  2590.0  876.0  1412.0
#
#         H      P      U  Hour  Minute
# 0  1455.0  310.0  811.0     1      32
# 1  1459.0  310.0  810.0     1      39
# 2  1459.0  310.0  810.0     1      39
# 3  1459.0  310.0  810.0     1      39
# 4  1458.0  310.0  810.0     1      40

# %% [markdown]
# ## Classify the carpark vacant status

# %%
df.describe()
# Out:
#         IsoWeekday            A            B            C            G  \
# count  6891.000000  6857.000000  6856.000000  6857.000000  6853.000000
# mean      4.010013   697.385883  1440.016044   723.302610   772.057931
# std       1.974669   604.831289  1074.659781   667.102289   569.929676
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000    63.000000   292.000000    54.000000   183.000000
# 50%       4.000000   739.000000  1592.500000   726.000000   826.000000
# 75%       6.000000  1057.000000  2575.000000  1071.000000  1372.000000
# max       7.000000  1786.000000  2646.000000  1921.000000  1495.000000
#
#                  H            P            U         Hour       Minute
# count  6851.000000  6855.000000  6855.000000  6891.000000  6891.000000
# mean    779.246679   209.576222   494.911451    11.484400    22.521840
# std     588.127668   106.128075   287.413354     6.928633    16.762178
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%     166.000000   121.000000   233.000000     5.000000    15.000000
# 50%     823.000000   254.000000   553.000000    11.000000    30.000000
# 75%    1399.000000   305.000000   779.000000    17.000000    39.500000
# max    1519.000000   317.000000   831.000000    23.000000    46.000000

# %%
# Define status for Carpark Zone A
def A_state(x):
    if x > 1057:
        return 4 # you are early!
    elif x > 739:
        return 3 # plenty of vacancy
    elif x > 63:
        return 2 # limited bay
    elif x > 0:
        return 1 # good luck
    else:
        return 0
    
df['A_State'] = df['A'].apply(A_state)
df.head()
# Out:
#                     DateTime  IsoWeekday      A       B      C       G  \
# 0 2018-09-20 01:32:30.850890           4  770.0  2592.0  875.0  1410.0
# 1 2018-09-20 01:39:01.932373           4  773.0  2590.0  876.0  1415.0
# 2 2018-09-20 01:39:40.024931           4  773.0  2591.0  876.0  1414.0
# 3 2018-09-20 01:39:52.258908           4  773.0  2591.0  876.0  1415.0
# 4 2018-09-20 01:40:49.225890           4  773.0  2590.0  876.0  1412.0
#
#         H      P      U  Hour  Minute  A_State
# 0  1455.0  310.0  811.0     1      32        3
# 1  1459.0  310.0  810.0     1      39        3
# 2  1459.0  310.0  810.0     1      39        3
# 3  1459.0  310.0  810.0     1      39        3
# 4  1458.0  310.0  810.0     1      40        3

# %% [markdown]
# ## Split into dataset of: Train, Validation, Test (70%-20%-10%)

# %%
df_train0, df_valid0, df_test0 = np.split(df.sample(frac=1), [int(.7*len(df)), int(.9*len(df))])

# select only Featured columns
df_train = df_train0[['A_State','Hour','Minute','IsoWeekday']]
df_valid = df_valid0[['A_State','Hour','Minute','IsoWeekday']]
df_test = df_test0[['A_State','Hour','Minute','IsoWeekday']]

print('Train set: {}'.format(df_train.shape))
print('Validate set: {}'.format(df_valid.shape))
print('Test set: {}'.format(df_test.shape))
# Out:
# Train set: (4823, 4)
# Validate set: (1378, 4)
# Test set: (690, 4)

# %% [markdown]
# ## Feature & Label

# %%
FEATURES_NUM = ['Hour','Minute','IsoWeekday']
LABEL = 'A_State'

# %% [markdown]
# ## Determine metrics for validation - Accuracy

# %%
def print_accuracy(model, df):
  metrics = model.evaluate(input_fn = tf.estimator.inputs.pandas_input_fn(
    x = df,
    y = df[LABEL],
    batch_size = 128,
    shuffle = False
  ))
  print('Accuracy on dataset = {}'.format(metrics['accuracy']))
    
#print_accuracy(model, df_valid)

# %% [markdown]
# ## Model: DNN Classifier

# %%
# DNNClassifier
OUTDIR = 'model/lab3_class_carpark'
tf.logging.set_verbosity(tf.logging.INFO)
shutil.rmtree(OUTDIR, ignore_errors = True) # start fresh each time

model = tf.estimator.DNNClassifier(
    hidden_units = [512, 312, 128], 
    feature_columns = [tf.feature_column.numeric_column('Hour'),
                       tf.feature_column.numeric_column('Minute'),
                       tf.feature_column.numeric_column('IsoWeekday')
                      ], 
    activation_fn = tf.nn.sigmoid,
    n_classes=5,
    optimizer=tf.train.AdamOptimizer(
      learning_rate=0.01,
      #l1_regularization_strength=0.001
    ),
    #loss_reduction='weighted_sum',
    model_dir = OUTDIR,
#    config=tf.estimator.RunConfig(save_summary_steps=2,
#                                  save_checkpoints_steps=2)
)

model.train(input_fn = tf.estimator.inputs.pandas_input_fn(
    x = df_train,
    y = df_train[LABEL],
    batch_size = 128,
    num_epochs = 50,
    shuffle = True
  ));

print_accuracy(model, df_valid)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': 'model/lab3_class_carpark', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000001D6796BD8D0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into model/lab3_class_carpark\model.ckpt.
# INFO:tensorflow:loss = 258.3675, step = 1
# INFO:tensorflow:global_step/sec: 130.818
# INFO:tensorflow:loss = 169.09714, step = 101 (0.760 sec)
# INFO:tensorflow:global_step/sec: 143.048
# INFO:tensorflow:loss = 141.70029, step = 201 (0.703 sec)
# INFO:tensorflow:global_step/sec: 142.235
# INFO:tensorflow:loss = 101.95183, step = 301 (0.703 sec)
# INFO:tensorflow:global_step/sec: 136.795
# INFO:tensorflow:loss = 123.03898, step = 401 (0.731 sec)
# INFO:tensorflow:global_step/sec: 142.235
# INFO:tensorflow:loss = 101.34785, step = 501 (0.699 sec)
# INFO:tensorflow:global_step/sec: 143.87
# INFO:tensorflow:loss = 85.48872, step = 601 (0.699 sec)
# INFO:tensorflow:global_step/sec: 136.795
# INFO:tensorflow:loss = 94.81534, step = 701 (0.727 sec)
# INFO:tensorflow:global_step/sec: 136.795
# INFO:tensorflow:loss = 79.59064, step = 801 (0.735 sec)
# INFO:tensorflow:global_step/sec: 144.702
# INFO:tensorflow:loss = 83.510735, step = 901 (0.687 sec)
# INFO:tensorflow:global_step/sec: 143.871
# INFO:tensorflow:loss = 102.22939, step = 1001 (0.695 sec)
# INFO:tensorflow:global_step/sec: 144.701
# INFO:tensorflow:loss = 69.84856, step = 1101 (0.691 sec)
# INFO:tensorflow:global_step/sec: 144.703
# INFO:tensorflow:loss = 77.32265, step = 1201 (0.691 sec)
# INFO:tensorflow:global_step/sec: 145.544
# INFO:tensorflow:loss = 82.85407, step = 1301 (0.891 sec)
# INFO:tensorflow:global_step/sec: 110.772
# INFO:tensorflow:loss = 89.35284, step = 1401 (0.699 sec)
# INFO:tensorflow:global_step/sec: 143.87
# INFO:tensorflow:loss = 46.405827, step = 1501 (0.695 sec)
# INFO:tensorflow:global_step/sec: 143.87
# INFO:tensorflow:loss = 68.80946, step = 1601 (0.695 sec)
# INFO:tensorflow:global_step/sec: 145.544
# INFO:tensorflow:loss = 80.740616, step = 1701 (0.687 sec)
# INFO:tensorflow:global_step/sec: 144.7
# INFO:tensorflow:loss = 84.54054, step = 1801 (0.691 sec)
# INFO:tensorflow:Saving checkpoints for 1884 into model/lab3_class_carpark\model.ckpt.
# INFO:tensorflow:Loss for final step: 58.18181.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-15-09:16:04
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model/lab3_class_carpark\model.ckpt-1884
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-15-09:16:05
# INFO:tensorflow:Saving dict for global step 1884: accuracy = 0.78447026, average_loss = 0.5392512, global_step = 1884, loss = 67.55347
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1884: model/lab3_class_carpark\model.ckpt-1884
# Accuracy on dataset = 0.78447026014328

# %% [markdown]
# ## Prediction

# %%
predictions = model.predict(input_fn = tf.estimator.inputs.pandas_input_fn(
#    x = pd.DataFrame({
#                      'Hour':[9,10,12],
#                      'Minute':[0,0,0],
#                      'IsoWeekday':[4,4,5]}),
    x = df_test,
    y = None,
    batch_size = 64,
    shuffle = False
  ))

for items in predictions:
  print(items)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model/lab3_class_carpark\model.ckpt-1884
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# {'logits': array([ 0.26504046,  2.8733363 ,  1.4843765 , -3.7997832 , -2.557054  ],
#       dtype=float32), 'probabilities': array([0.0554401 , 0.7526491 , 0.18766141, 0.00095169, 0.00329765],
#       dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-4.3693743, -9.77875  , -0.3319178,  5.4110975,  1.8310905],
#       dtype=float32), 'probabilities': array([5.4837608e-05, 2.4536709e-07, 3.1083047e-03, 9.6980280e-01,
#        2.7033739e-02], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 3.55969   ,  2.7824867 , -0.48370007, -5.7998214 , -2.1324072 ],
#       dtype=float32), 'probabilities': array([6.7536241e-01, 3.1045723e-01, 1.1844447e-02, 5.8177189e-05,
#        2.2776683e-03], dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-1.3116331,  1.4341016,  2.554665 , -1.7287349, -2.1091013],
#       dtype=float32), 'probabilities': array([0.01527867, 0.2379814 , 0.7297894 , 0.01006794, 0.00688255],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-2.096274 , -5.5218596,  1.0223126,  1.951821 ,  4.003148 ],
#       dtype=float32), 'probabilities': array([1.89920806e-03, 6.17816913e-05, 4.29494344e-02, 1.08802214e-01,
#        8.46287370e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 3.4941144,  2.742079 , -0.739308 , -5.5419345, -1.8915057],
#       dtype=float32), 'probabilities': array([6.7086637e-01, 3.1625047e-01, 9.7293556e-03, 7.9860096e-05,
#        3.0739084e-03], dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-4.98949   , -8.501519  ,  1.1643384 ,  6.856027  ,  0.13443077],
#       dtype=float32), 'probabilities': array([7.1378954e-06, 2.1296857e-07, 3.3584896e-03, 9.9543506e-01,
#        1.1991148e-03], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-4.3559685, -3.5551453,  2.9635603, -0.8174381, -1.3455381],
#       dtype=float32), 'probabilities': array([6.3798623e-04, 1.4210338e-03, 9.6303523e-01, 2.1957122e-02,
#        1.2948653e-02], dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-1.648753 , -1.8532023,  1.603204 , -1.2259114, -2.139464 ],
#       dtype=float32), 'probabilities': array([0.03356331, 0.02735732, 0.86730474, 0.05122742, 0.02054716],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 2.479996  ,  2.6466699 , -1.9774195 , -4.925328  , -0.28206694],
#       dtype=float32), 'probabilities': array([4.4311890e-01, 5.2348691e-01, 5.1367613e-03, 2.6941948e-04,
#        2.7987987e-02], dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-0.8042805, -5.4965487, -0.4332128,  2.8520026,  1.1052213],
#       dtype=float32), 'probabilities': array([2.0865789e-02, 1.9125326e-04, 3.0240396e-02, 8.0786425e-01,
#        1.4083834e-01], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ -3.4918904, -11.880873 ,  -3.5912433,  -0.5991651,   8.729753 ],
#       dtype=float32), 'probabilities': array([4.9222658e-06, 1.1191186e-09, 4.4567373e-06, 8.8809604e-05,
#        9.9990177e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 11.4127865, -12.102532 ,  -7.74214  ,  -7.4329333,  17.615673 ],
#       dtype=float32), 'probabilities': array([2.0194943e-03, 1.2378552e-13, 9.6908948e-12, 1.3202322e-11,
#        9.9798054e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 1.8436033, -5.1057506,  2.0487378,  6.385856 , -2.186511 ],
#       dtype=float32), 'probabilities': array([1.0400573e-02, 9.9768004e-06, 1.2768686e-02, 9.7663587e-01,
#        1.8484220e-04], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-3.698868 , -3.234425 ,  2.2140434, -0.8552722, -0.7119017],
#       dtype=float32), 'probabilities': array([0.00244275, 0.00388672, 0.90328175, 0.0419601 , 0.04842855],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-2.1469576 , -1.0309203 ,  0.98456115, -2.1595306 , -1.3842739 ],
#       dtype=float32), 'probabilities': array([0.03323031, 0.10144328, 0.7612648 , 0.03281512, 0.07124654],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-0.7786691,  1.1852173,  0.9922725, -2.2513533, -1.0011876],
#       dtype=float32), 'probabilities': array([0.06651959, 0.47408324, 0.39089468, 0.01525355, 0.05324896],
#       dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object)}
# {'logits': array([ 2.739525  ,  2.1675186 , -2.432772  , -5.1753044 ,  0.18249297],
#       dtype=float32), 'probabilities': array([6.0680968e-01, 3.4247842e-01, 3.4415370e-03, 2.2165923e-04,
#        4.7048692e-02], dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object)}
# {'logits': array([ 1.8703417 ,  2.454888  , -1.5568906 , -4.3774014 , -0.43091446],
#       dtype=float32), 'probabilities': array([0.34144592, 0.6126144 , 0.01108904, 0.00066063, 0.03419   ],
#       dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-5.331184 , -8.788794 ,  0.7833665,  4.359557 ,  1.8074245],
#       dtype=float32), 'probabilities': array([5.5927438e-05, 1.7619922e-06, 2.5301147e-02, 9.0419084e-01,
#        7.0450321e-02], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 2.2890377,  1.7924125, -1.0986034, -4.6845684, -1.0011101],
#       dtype=float32), 'probabilities': array([5.9504187e-01, 3.6213121e-01, 2.0105448e-02, 5.5712013e-04,
#        2.2164324e-02], dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object)}
# {'logits': array([ 2.534722 ,  4.110147 ,  2.3031173, -5.062248 , -4.0643253],
#       dtype=float32), 'probabilities': array([1.5087694e-01, 7.2915727e-01, 1.1968457e-01, 7.5735647e-05,
#        2.0544366e-04], dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-3.5289848 , -4.0027566 ,  1.2235787 ,  3.3244286 , -0.21808082],
#       dtype=float32), 'probabilities': array([9.1573253e-04, 5.7018036e-04, 1.0611599e-01, 8.6729801e-01,
#        2.5100138e-02], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-8.8243475 , -7.422581  ,  2.003884  ,  5.676989  ,  0.43173158],
#       dtype=float32), 'probabilities': array([4.8868458e-07, 1.9852180e-06, 2.4641663e-02, 9.7024024e-01,
#        5.1155570e-03], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ -5.7195916, -10.587322 ,  -0.6316427,   4.8530755,   2.8254855],
#       dtype=float32), 'probabilities': array([2.2544284e-05, 1.7338363e-07, 3.6534613e-03, 8.8041496e-01,
#        1.1590876e-01], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 1.9523407 ,  2.543478  , -1.5575956 , -4.439707  , -0.47434992],
#       dtype=float32), 'probabilities': array([3.4177011e-01, 6.1725092e-01, 1.0218522e-02, 5.7240459e-04,
#        3.0188095e-02], dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-0.26366305, -9.166021  , -0.25605825,  2.8492923 ,  5.9418173 ],
#       dtype=float32), 'probabilities': array([1.9232538e-03, 2.6169272e-07, 1.9379361e-03, 4.3248996e-02,
#        9.5288956e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-2.0963514 , -0.71570265,  1.3174613 , -2.2500038 , -1.7599305 ],
#       dtype=float32), 'probabilities': array([0.02658455, 0.10573953, 0.80766135, 0.02279811, 0.03721647],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-6.5515723 , -7.6815085 ,  3.434609  ,  2.586516  ,  0.40313268],
#       dtype=float32), 'probabilities': array([3.1175437e-05, 1.0071345e-05, 6.7726082e-01, 2.9002392e-01,
#        3.2674018e-02], dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 2.0916932,  2.4175127,  2.3101015, -3.680036 , -3.6467204],
#       dtype=float32), 'probabilities': array([0.27505818, 0.38100103, 0.3421985 , 0.00085663, 0.00088565],
#       dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object)}
# {'logits': array([ 1.068705  , -7.8383255 , -0.18837705,  2.6227775 ,  4.652154  ],
#       dtype=float32), 'probabilities': array([2.3802275e-02, 3.2236228e-06, 6.7713410e-03, 1.1260133e-01,
#        8.5682184e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 14.342494 , -16.448843 ,  -7.1590247, -10.04933  ,  23.617346 ],
#       dtype=float32), 'probabilities': array([9.3743758e-05, 3.9758920e-18, 4.3047824e-14, 2.3917066e-15,
#        9.9990630e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ -7.100182  , -11.428174  ,  -0.82951224,   5.361369  ,
#          3.2756734 ], dtype=float32), 'probabilities': array([3.43853458e-06, 4.53680968e-08, 1.81840640e-03, 8.87884557e-01,
#        1.10293604e-01], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-3.777847  , -9.781635  , -0.55606854,  4.80085   ,  2.4337    ],
#       dtype=float32), 'probabilities': array([1.7118243e-04, 4.2271458e-07, 4.2920029e-03, 9.1020679e-01,
#        8.5329652e-02], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 1.1615257,  1.2545295,  2.1286345, -0.9941608, -3.5773711],
#       dtype=float32), 'probabilities': array([0.20608501, 0.22617127, 0.5420713 , 0.02386952, 0.00180289],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 0.6849171 ,  0.28262874,  0.56305504, -3.4393883 , -1.9470882 ],
#       dtype=float32), 'probabilities': array([0.3784772 , 0.25312093, 0.33505467, 0.00612177, 0.02722541],
#       dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object)}
# {'logits': array([ 1.068705  , -7.8383255 , -0.18837705,  2.6227775 ,  4.652154  ],
#       dtype=float32), 'probabilities': array([2.3802275e-02, 3.2236228e-06, 6.7713410e-03, 1.1260133e-01,
#        8.5682184e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-4.061016  , -2.3966892 ,  2.7751288 ,  1.3245142 ,  0.38811302],
#       dtype=float32), 'probabilities': array([0.00080583, 0.0042565 , 0.7501436 , 0.17585327, 0.06894084],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-3.3868015 , -4.984085  ,  0.95057356,  2.8209376 ,  0.3593943 ],
#       dtype=float32), 'probabilities': array([1.62167696e-03, 3.28301423e-04, 1.24068715e-01, 8.05287719e-01,
#        6.86936229e-02], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-5.0608993 , -4.128793  ,  2.6709473 , -0.06312853, -1.2436779 ],
#       dtype=float32), 'probabilities': array([4.0372898e-04, 1.0254130e-03, 9.2042488e-01, 5.9785288e-02,
#        1.8360658e-02], dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 3.7735379,  4.9720807,  2.497122 , -4.558467 , -4.8518586],
#       dtype=float32), 'probabilities': array([2.1764025e-01, 7.2153890e-01, 6.0729381e-02, 5.2383599e-05,
#        3.9064034e-05], dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object)}
# {'logits': array([ 5.4206934,  4.6475916,  2.249671 , -4.74987  , -4.721154 ],
#       dtype=float32), 'probabilities': array([6.6506279e-01, 3.0697909e-01, 2.7906483e-02, 2.5459118e-05,
#        2.6200780e-05], dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object)}
# {'logits': array([ 0.05654626, -5.3376217 , -0.73191893,  3.169756  ,  1.0147893 ],
#       dtype=float32), 'probabilities': array([3.7651561e-02, 1.7105101e-04, 1.7114215e-02, 8.4690130e-01,
#        9.8161846e-02], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 2.479996  ,  2.6466699 , -1.9774195 , -4.925328  , -0.28206694],
#       dtype=float32), 'probabilities': array([4.4311890e-01, 5.2348691e-01, 5.1367613e-03, 2.6941948e-04,
#        2.7987987e-02], dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object)}
# {'logits': array([ 1.5618043, -5.2628236,  2.746706 ,  6.7245708, -2.622674 ],
#       dtype=float32), 'probabilities': array([5.5886637e-03, 6.0730904e-06, 1.8276973e-02, 9.7604305e-01,
#        8.5116226e-05], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([  4.73648  , -10.088855 ,  -2.2204213,  -5.057396 ,  10.683308 ],
#       dtype=float32), 'probabilities': array([2.6072983e-03, 9.4979336e-10, 2.4822584e-06, 1.4546694e-07,
#        9.9739009e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-2.0073307 , -4.032956  ,  0.81683624,  0.8589192 ,  3.5210676 ],
#       dtype=float32), 'probabilities': array([3.4808002e-03, 4.5915708e-04, 5.8640730e-02, 6.1161160e-02,
#        8.7625819e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 0.39713067,  0.1972389 ,  0.2797232 , -3.1146026 , -1.3329504 ],
#       dtype=float32), 'probabilities': array([0.34303465, 0.28088343, 0.30503425, 0.01023792, 0.06080977],
#       dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-0.37057346,  1.3872311 ,  0.7412584 , -2.4888554 , -1.0344086 ],
#       dtype=float32), 'probabilities': array([0.0954679 , 0.55368435, 0.29021502, 0.01147887, 0.04915385],
#       dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-4.520542  , -4.209091  ,  2.1277416 , -0.1856488 , -0.41751182],
#       dtype=float32), 'probabilities': array([0.0010981 , 0.00149935, 0.84713835, 0.08380342, 0.06646069],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-1.454983 , -7.5180244, -0.9429034,  3.6850739,  1.8555307],
#       dtype=float32), 'probabilities': array([4.9801860e-03, 1.1590442e-05, 8.3107222e-03, 8.5024440e-01,
#        1.3645306e-01], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-4.440417  , -9.23043   ,  0.24523667,  5.6878986 ,  1.0832989 ],
#       dtype=float32), 'probabilities': array([3.9366849e-05, 3.2723088e-07, 4.2666197e-03, 9.8582977e-01,
#        9.8639214e-03], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-4.3431387 , -4.142776  ,  2.1125665 , -0.62361014, -0.6339525 ],
#       dtype=float32), 'probabilities': array([0.00138771, 0.00169557, 0.8830333 , 0.05723619, 0.05664727],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ -0.62851995, -10.856617  ,  -3.5714192 ,  -1.4328693 ,
#          7.472266  ], dtype=float32), 'probabilities': array([3.0316264e-04, 1.0956433e-08, 1.5980508e-05, 1.3562862e-04,
#        9.9954516e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-3.0099535, -1.0848973,  3.1509206,  0.5525218, -1.1836654],
#       dtype=float32), 'probabilities': array([0.00191147, 0.01310412, 0.90573287, 0.06737983, 0.01187171],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 3.5858083 ,  3.147517  , -0.31086257, -6.047008  , -2.329468  ],
#       dtype=float32), 'probabilities': array([5.9944463e-01, 3.8672438e-01, 1.2174369e-02, 3.9288923e-05,
#        1.6172499e-03], dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-4.269592 , -8.85563  , -0.2543024,  4.753467 ,  1.6408415],
#       dtype=float32), 'probabilities': array([1.14712864e-04, 1.16928743e-06, 6.35960465e-03, 9.51210856e-01,
#        4.23136689e-02], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 4.581235 ,  4.4611793,  2.0726802, -4.3312283, -4.451242 ],
#       dtype=float32), 'probabilities': array([5.0799817e-01, 4.5052886e-01, 4.1343831e-02, 6.8427165e-05,
#        6.0688650e-05], dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-4.1045637 , -4.851902  , -0.38584402,  1.1662366 ,  0.6280017 ],
#       dtype=float32), 'probabilities': array([0.00285027, 0.00134996, 0.11746435, 0.5545825 , 0.3237529 ],
#       dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 2.270782 ,  2.0112803, -0.9739746, -4.426537 , -1.1349698],
#       dtype=float32), 'probabilities': array([0.5420553 , 0.41816095, 0.02112826, 0.00066901, 0.01798641],
#       dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-1.0039914 , -9.36793   , -2.9904532 , -0.41473508,  7.4056835 ],
#       dtype=float32), 'probabilities': array([2.2255657e-04, 5.1883365e-08, 3.0530275e-05, 4.0119098e-04,
#        9.9934560e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-3.4261088, -8.355265 , -0.574352 ,  4.2669096,  1.6985395],
#       dtype=float32), 'probabilities': array([4.2026973e-04, 3.0396454e-06, 7.2783055e-03, 9.2164481e-01,
#        7.0653655e-02], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-4.3585687, -2.458879 ,  2.9779713,  3.1049733, -0.5791502],
#       dtype=float32), 'probabilities': array([3.0028436e-04, 2.0070465e-03, 4.6105373e-01, 5.2348930e-01,
#        1.3149623e-02], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-2.0073307 , -4.032956  ,  0.81683624,  0.8589192 ,  3.5210676 ],
#       dtype=float32), 'probabilities': array([3.4808002e-03, 4.5915708e-04, 5.8640730e-02, 6.1161160e-02,
#        8.7625819e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 0.09254643,  1.6179049 ,  0.41253406, -2.7949882 , -1.0386598 ],
#       dtype=float32), 'probabilities': array([0.13601263, 0.6252216 , 0.18730444, 0.00757772, 0.04388363],
#       dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-2.9107516, -6.4732313,  1.7832928,  5.523617 , -1.1550608],
#       dtype=float32), 'probabilities': array([2.1192408e-04, 6.0119437e-06, 2.3162091e-02, 9.7539347e-01,
#        1.2264985e-03], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-0.2873141 , -4.18033   ,  0.39669567,  0.3343995 ,  1.2822287 ],
#       dtype=float32), 'probabilities': array([0.10342588, 0.00210821, 0.20497029, 0.19259101, 0.49690458],
#       dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-1.7658097, -1.3362572,  1.3772739, -1.7630757, -1.2666075],
#       dtype=float32), 'probabilities': array([0.03525853, 0.05417719, 0.81712407, 0.03535505, 0.05808512],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ -7.4732437 , -10.2943325 ,   0.25211632,   5.858565  ,
#          2.110892  ], dtype=float32), 'probabilities': array([1.5790426e-06, 9.4017899e-08, 3.5766365e-03, 9.7347438e-01,
#        2.2947263e-02], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-0.5578241, -7.6826386, -1.4143971,  4.2672715,  1.9913406],
#       dtype=float32), 'probabilities': array([7.2035608e-03, 5.7980192e-06, 3.0587378e-03, 8.9755207e-01,
#        9.2179731e-02], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-0.79553044, -0.2721023 ,  1.8903875 , -0.6946269 , -2.6878407 ],
#       dtype=float32), 'probabilities': array([0.0537162 , 0.09066238, 0.7881059 , 0.05941924, 0.00809628],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-2.7526882 , -0.64849585,  2.0273001 , -0.53087974, -0.16023159],
#       dtype=float32), 'probabilities': array([0.00662734, 0.05434738, 0.7893363 , 0.06113061, 0.08855827],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 3.55969   ,  2.7824867 , -0.48370007, -5.7998214 , -2.1324072 ],
#       dtype=float32), 'probabilities': array([6.7536241e-01, 3.1045723e-01, 1.1844447e-02, 5.8177189e-05,
#        2.2776683e-03], dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object)}
# {'logits': array([ 2.1149058 ,  2.4984221 , -1.638867  , -4.4919753 , -0.42481732],
#       dtype=float32), 'probabilities': array([3.8893801e-01, 5.7074142e-01, 9.1125006e-03, 5.2547053e-04,
#        3.0682633e-02], dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object)}
# {'logits': array([ -7.868734  , -10.425223  ,  -0.16765901,   5.4554896 ,
#          2.2340488 ], dtype=float32), 'probabilities': array([1.5662662e-06, 1.2150566e-07, 3.4625814e-03, 9.5830184e-01,
#        3.8233876e-02], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-2.838938 , -7.7163005, -0.422707 ,  4.3000946,  1.3541865],
#       dtype=float32), 'probabilities': array([7.4702181e-04, 5.6901190e-06, 8.3692959e-03, 9.4140315e-01,
#        4.9474798e-02], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 2.1309552 ,  2.4138722 , -1.9097322 , -4.614931  , -0.20362025],
#       dtype=float32), 'probabilities': array([4.0939856e-01, 5.4326987e-01, 7.1994280e-03, 4.8133242e-04,
#        3.9650906e-02], dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-4.1470413 , -4.2017417 ,  2.2758603 , -0.5899199 , -0.42586625],
#       dtype=float32), 'probabilities': array([0.0014407 , 0.00136401, 0.88716215, 0.05051384, 0.05951934],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-7.0678325 , -7.3380466 ,  1.7491711 ,  4.9657516 ,  0.31279838],
#       dtype=float32), 'probabilities': array([5.6603335e-06, 4.3200575e-06, 3.8196035e-02, 9.5271146e-01,
#        9.0825865e-03], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 10.176426 , -12.16015  ,  -7.4715276,  -6.94435  ,  16.989359 ],
#       dtype=float32), 'probabilities': array([1.0982560e-03, 2.1880219e-13, 2.3784551e-11, 4.0294466e-11,
#        9.9890172e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-2.7144792, -7.8415356, -0.0624353,  3.8439765,  1.6469679],
#       dtype=float32), 'probabilities': array([1.2519703e-03, 7.4291897e-06, 1.7756687e-02, 8.8286650e-01,
#        9.8117463e-02], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 1.1454188, -9.363694 , -3.3726585, -1.1703252,  8.885022 ],
#       dtype=float32), 'probabilities': array([4.3503405e-04, 1.1870624e-08, 4.7462122e-06, 4.2934698e-05,
#        9.9951732e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 1.5618043, -5.2628236,  2.746706 ,  6.7245708, -2.622674 ],
#       dtype=float32), 'probabilities': array([5.5886637e-03, 6.0730904e-06, 1.8276973e-02, 9.7604305e-01,
#        8.5116226e-05], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-2.3960142 , -2.2158074 ,  1.5595385 ,  0.21820655,  1.4979868 ],
#       dtype=float32), 'probabilities': array([0.00853348, 0.01021854, 0.44565687, 0.116538  , 0.41905308],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-8.50187   , -8.098696  ,  1.9322723 ,  4.9210258 ,  0.55095494],
#       dtype=float32), 'probabilities': array([1.3930785e-06, 2.0848347e-06, 4.7365915e-02, 9.4073004e-01,
#        1.1900557e-02], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-4.3480444 , -4.343621  ,  2.795991  , -0.41171974, -0.48880106],
#       dtype=float32), 'probabilities': array([7.3142565e-04, 7.3466840e-04, 9.2637181e-01, 3.7470911e-02,
#        3.4691121e-02], dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-2.6809294 , -3.0226233 ,  1.2234994 ,  2.1059651 , -0.24054933],
#       dtype=float32), 'probabilities': array([0.00547231, 0.00388844, 0.27154568, 0.65628564, 0.06280795],
#       dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-9.052957 , -7.8577814,  1.8651087,  5.500263 ,  0.5009768],
#       dtype=float32), 'probabilities': array([4.6287548e-07, 1.5294039e-06, 2.5534051e-02, 9.6793735e-01,
#        6.5265642e-03], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-1.1539265, -1.2943652,  1.6844193, -1.8028504, -2.3546648],
#       dtype=float32), 'probabilities': array([0.05055603, 0.04393202, 0.863875  , 0.02642098, 0.01521595],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 2.739525  ,  2.1675186 , -2.432772  , -5.1753044 ,  0.18249297],
#       dtype=float32), 'probabilities': array([6.0680968e-01, 3.4247842e-01, 3.4415370e-03, 2.2165923e-04,
#        4.7048692e-02], dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object)}
# {'logits': array([ 2.0714827,  4.4063134,  2.8965826, -5.2188306, -4.5394125],
#       dtype=float32), 'probabilities': array([7.3465407e-02, 7.5872958e-01, 1.6765606e-01, 5.0111808e-05,
#        9.8856988e-05], dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object)}
# {'logits': array([ 1.8499163,  2.2977273,  2.4036872, -3.5205646, -3.7336183],
#       dtype=float32), 'probabilities': array([0.23185204, 0.36282128, 0.40337646, 0.00107855, 0.00087159],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-4.3559685, -3.5551453,  2.9635603, -0.8174381, -1.3455381],
#       dtype=float32), 'probabilities': array([6.3798623e-04, 1.4210338e-03, 9.6303523e-01, 2.1957122e-02,
#        1.2948653e-02], dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 4.885578 ,  4.07764  ,  2.0106418, -3.911744 , -4.4729147],
#       dtype=float32), 'probabilities': array([6.65586948e-01, 2.96702862e-01, 3.75522375e-02, 1.00594974e-04,
#        5.73935395e-05], dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object)}
# {'logits': array([ 2.5948703 ,  2.5541327 , -2.1011221 , -4.9091144 , -0.15702677],
#       dtype=float32), 'probabilities': array([4.9174598e-01, 4.7211596e-01, 4.4905255e-03, 2.7089549e-04,
#        3.1376686e-02], dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-2.9107516, -6.4732313,  1.7832928,  5.523617 , -1.1550608],
#       dtype=float32), 'probabilities': array([2.1192408e-04, 6.0119437e-06, 2.3162091e-02, 9.7539347e-01,
#        1.2264985e-03], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 0.8307737,  3.9207737,  3.0156317, -4.2124686, -4.2257495],
#       dtype=float32), 'probabilities': array([3.1368326e-02, 6.8938428e-01, 2.7884519e-01, 2.0241327e-04,
#        1.9974283e-04], dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-2.1797857, -1.6274564,  1.4316472, -1.6300308, -1.1422942],
#       dtype=float32), 'probabilities': array([0.0225676 , 0.03920658, 0.83543134, 0.03910578, 0.06368869],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-3.2544682 , -0.31004363,  3.1973917 ,  0.21318242, -1.4869785 ],
#       dtype=float32), 'probabilities': array([0.00144551, 0.0274643 , 0.91628015, 0.04634497, 0.0084651 ],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-0.7591028, -6.898775 , -1.0710684,  4.007976 ,  1.5159478],
#       dtype=float32), 'probabilities': array([7.7496632e-03, 1.6705399e-05, 5.6728064e-03, 9.1116887e-01,
#        7.5391911e-02], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-1.5906342 , -1.1639807 ,  1.6574693 ,  0.13682273, -2.3190722 ],
#       dtype=float32), 'probabilities': array([0.02908449, 0.04456098, 0.74867773, 0.16363887, 0.01403799],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-6.840668 , -4.3435965,  5.363172 ,  6.476076 , -3.212492 ],
#       dtype=float32), 'probabilities': array([1.23933569e-06, 1.50540445e-05, 2.47314304e-01, 7.52622724e-01,
#        4.66536549e-05], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-3.1521277 , -2.7857237 ,  1.9436389 , -0.8971425 , -0.61573094],
#       dtype=float32), 'probabilities': array([0.00532083, 0.00767549, 0.8690452 , 0.05073488, 0.06722366],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-2.062367  ,  0.93263525,  2.978404  , -1.2577751 , -2.058016  ],
#       dtype=float32), 'probabilities': array([0.00559238, 0.111766  , 0.86452144, 0.01250335, 0.00561677],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 2.4322324 ,  2.279008  , -2.1558383 , -4.728048  ,  0.02731204],
#       dtype=float32), 'probabilities': array([5.1042306e-01, 4.3791088e-01, 5.1922603e-03, 3.9651542e-04,
#        4.6077263e-02], dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-9.052957 , -7.8577814,  1.8651087,  5.500263 ,  0.5009768],
#       dtype=float32), 'probabilities': array([4.6287548e-07, 1.5294039e-06, 2.5534051e-02, 9.6793735e-01,
#        6.5265642e-03], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-1.7681293, -5.137397 ,  1.6349434,  3.1401849,  1.6384139],
#       dtype=float32), 'probabilities': array([5.0848536e-03, 1.7499433e-04, 1.5283194e-01, 6.8854487e-01,
#        1.5336327e-01], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-5.8858037, -9.400587 ,  0.6658101,  5.209433 ,  1.6432855],
#       dtype=float32), 'probabilities': array([1.4615709e-05, 4.3487964e-07, 1.0236456e-02, 9.6254271e-01,
#        2.7205819e-02], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-7.880332 , -8.047188 ,  1.4725758,  5.285433 ,  0.512859 ],
#       dtype=float32), 'probabilities': array([1.8582884e-06, 1.5727097e-06, 2.1430353e-02, 9.7035831e-01,
#        8.2078530e-03], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-2.3469124,  1.1760795,  3.2398787, -1.1671722, -2.55362  ],
#       dtype=float32), 'probabilities': array([0.00326979, 0.1107989 , 0.87263376, 0.01063834, 0.00265918],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ -3.6036546 , -10.104343  ,  -2.2659826 ,  -0.71152985,
#          6.8524714 ], dtype=float32), 'probabilities': array([2.8752575e-05, 4.3198035e-08, 1.0955203e-04, 5.1845459e-04,
#        9.9934322e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-2.942717 , -5.7626038,  1.7673115,  3.1523275,  2.1126971],
#       dtype=float32), 'probabilities': array([1.4032364e-03, 8.3650710e-05, 1.5583688e-01, 6.2255120e-01,
#        2.2012497e-01], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-2.6310818, -2.4960105,  1.3697728,  1.6253647, -0.1547314],
#       dtype=float32), 'probabilities': array([0.00718153, 0.00822012, 0.39243367, 0.5067204 , 0.08544419],
#       dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-3.4261088, -8.355265 , -0.574352 ,  4.2669096,  1.6985395],
#       dtype=float32), 'probabilities': array([4.2026973e-04, 3.0396454e-06, 7.2783055e-03, 9.2164481e-01,
#        7.0653655e-02], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-2.1797857, -1.6274564,  1.4316472, -1.6300308, -1.1422942],
#       dtype=float32), 'probabilities': array([0.0225676 , 0.03920658, 0.83543134, 0.03910578, 0.06368869],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-4.1470413 , -4.2017417 ,  2.2758603 , -0.5899199 , -0.42586625],
#       dtype=float32), 'probabilities': array([0.0014407 , 0.00136401, 0.88716215, 0.05051384, 0.05951934],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-4.852374  , -3.9364192 ,  2.560064  ,  0.13819629, -0.8185484 ],
#       dtype=float32), 'probabilities': array([5.3663715e-04, 1.3411427e-03, 8.8891828e-01, 7.8896545e-02,
#        3.0307427e-02], dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 4.521668 ,  3.892399 ,  2.236171 , -4.1057982, -4.4510818],
#       dtype=float32), 'probabilities': array([6.1161667e-01, 3.2598028e-01, 6.2215786e-02, 1.0955151e-04,
#        7.7564611e-05], dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object)}
# {'logits': array([ 1.1532136,  2.0878553, -1.0756325, -3.8807335, -0.3800695],
#       dtype=float32), 'probabilities': array([0.25797847, 0.6568908 , 0.02777204, 0.00168023, 0.05567844],
#       dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object)}
# {'logits': array([ 4.271901 ,  4.4233155,  2.1157627, -4.3783135, -4.3586054],
#       dtype=float32), 'probabilities': array([4.3867275e-01, 5.1038641e-01, 5.0785720e-02, 7.6806886e-05,
#        7.8335586e-05], dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object)}
# {'logits': array([ 7.0032535, -9.870421 , -4.8405876, -3.8263054, 13.756321 ],
#       dtype=float32), 'probabilities': array([1.1659324e-03, 5.4768280e-11, 8.3744940e-09, 2.3091692e-08,
#        9.9883407e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 1.8773056 ,  1.6854205 , -0.48704186, -4.500936  , -1.5104991 ],
#       dtype=float32), 'probabilities': array([0.5115369 , 0.42222342, 0.04808991, 0.00086864, 0.01728113],
#       dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object)}
# {'logits': array([ 1.1454188, -9.363694 , -3.3726585, -1.1703252,  8.885022 ],
#       dtype=float32), 'probabilities': array([4.3503405e-04, 1.1870624e-08, 4.7462122e-06, 4.2934698e-05,
#        9.9951732e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ -6.7728477 , -11.3655205 ,  -0.82197416,   5.261798  ,
#          3.2883458 ], dtype=float32), 'probabilities': array([5.2003766e-06, 5.2657672e-08, 1.9974045e-03, 8.7622315e-01,
#        1.2177423e-01], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-3.557005 , -3.8636873,  2.112135 ,  1.9840977,  2.0751512],
#       dtype=float32), 'probabilities': array([0.00121103, 0.00089118, 0.35093844, 0.30876288, 0.33819652],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ -6.7728477 , -11.3655205 ,  -0.82197416,   5.261798  ,
#          3.2883458 ], dtype=float32), 'probabilities': array([5.2003766e-06, 5.2657672e-08, 1.9974045e-03, 8.7622315e-01,
#        1.2177423e-01], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 11.485368 , -11.382121 ,  -7.5544024,  -7.165612 ,  16.674185 ],
#       dtype=float32), 'probabilities': array([5.5476543e-03, 6.4995839e-13, 2.9870453e-11, 4.4064745e-11,
#        9.9445230e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 2.270782 ,  2.0112803, -0.9739746, -4.426537 , -1.1349698],
#       dtype=float32), 'probabilities': array([0.5420553 , 0.41816095, 0.02112826, 0.00066901, 0.01798641],
#       dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-0.9436368,  1.0836412,  1.0307058, -2.160102 , -0.9356977],
#       dtype=float32), 'probabilities': array([0.05848118, 0.4440703 , 0.42117465, 0.01732655, 0.05894731],
#       dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object)}
# {'logits': array([ 0.66515255,  2.4817822 ,  0.38643914, -3.7048607 , -1.6461104 ],
#       dtype=float32), 'probabilities': array([0.12469394, 0.7670039 , 0.09436297, 0.00157751, 0.01236166],
#       dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-4.381249  , -9.039769  ,  0.09530053,  5.5064616 ,  1.2454538 ],
#       dtype=float32), 'probabilities': array([4.9866307e-05, 4.7275682e-07, 4.3847822e-03, 9.8171484e-01,
#        1.3850110e-02], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-2.5706022, -6.064544 ,  0.9527073,  1.8804351,  4.4911833],
#       dtype=float32), 'probabilities': array([7.7689876e-04, 2.3602879e-05, 2.6334094e-02, 6.6592515e-02,
#        9.0627289e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-5.519416  , -4.580765  ,  3.8487184 , -0.08027369, -1.2323104 ],
#       dtype=float32), 'probabilities': array([8.3223698e-05, 2.1276392e-04, 9.7448719e-01, 1.9161813e-02,
#        6.0549881e-03], dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-0.65112907, -4.986222  ,  0.36818066, -0.05751729,  2.0824194 ],
#       dtype=float32), 'probabilities': array([4.7659244e-02, 6.2436744e-04, 1.3207716e-01, 8.6287811e-02,
#        7.3335141e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 2.46237  ,  2.5705466, -1.5527707, -4.6297026, -0.7706742],
#       dtype=float32), 'probabilities': array([4.6028772e-01, 5.1287311e-01, 8.3037838e-03, 3.8280836e-04,
#        1.8152488e-02], dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-1.5718606 , -7.53863   ,  0.70039034,  3.0218315 ,  4.1449814 ],
#       dtype=float32), 'probabilities': array([2.4183448e-03, 6.1970254e-06, 2.3460869e-02, 2.3907448e-01,
#        7.3504007e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 0.15006614, -7.8013725 ,  0.12401828,  2.8059797 ,  4.525605  ],
#       dtype=float32), 'probabilities': array([1.0449836e-02, 3.6799629e-06, 1.0181151e-02, 1.4878461e-01,
#        8.3058071e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-1.7618327, -5.568421 ,  1.4712099,  3.1041608,  2.0900545],
#       dtype=float32), 'probabilities': array([4.9197930e-03, 1.0933686e-04, 1.2474967e-01, 6.3858831e-01,
#        2.3163287e-01], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-2.7023308 , -2.583309  ,  1.6646818 ,  0.46836367,  1.672801  ],
#       dtype=float32), 'probabilities': array([0.00542863, 0.00611478, 0.42781857, 0.12933177, 0.43130624],
#       dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-1.8911396, -2.965537 ,  2.4642072,  3.8116603, -1.8687394],
#       dtype=float32), 'probabilities': array([0.00263183, 0.00089878, 0.20500353, 0.78877443, 0.00269145],
#       dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 2.7873194 , -6.415798  , -0.76459503, -2.3450842 ,  4.260018  ],
#       dtype=float32), 'probabilities': array([1.8533415e-01, 1.8667772e-05, 5.3134742e-03, 1.0939081e-03,
#        8.0823982e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 0.8307737,  3.9207737,  3.0156317, -4.2124686, -4.2257495],
#       dtype=float32), 'probabilities': array([3.1368326e-02, 6.8938428e-01, 2.7884519e-01, 2.0241327e-04,
#        1.9974283e-04], dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object)}
# {'logits': array([ 2.7869868, -7.99677  , -1.4427545, -3.2371874,  8.7170925],
#       dtype=float32), 'probabilities': array([2.6510339e-03, 5.4965334e-08, 3.8588856e-05, 6.4143064e-06,
#        9.9730384e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 12.057429 , -11.380256 ,  -7.701416 ,  -7.3827376,  16.971468 ],
#       dtype=float32), 'probabilities': array([7.2892499e-03, 4.8286527e-13, 1.9121649e-11, 2.6298162e-11,
#        9.9271071e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ -1.2557181, -11.355135 ,   2.8731406,  -1.4946393,   7.0731144],
#       dtype=float32), 'probabilities': array([2.3778528e-04, 9.7738129e-09, 1.4768129e-02, 1.8725042e-04,
#        9.8480678e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-2.4112105, -5.643958 ,  1.6603199,  3.1416388,  2.0540056],
#       dtype=float32), 'probabilities': array([2.4715923e-03, 9.7501754e-05, 1.4495061e-01, 6.3760048e-01,
#        2.1487978e-01], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-3.3958452 , -3.0983496 ,  2.7108994 ,  2.6145086 , -0.22929567],
#       dtype=float32), 'probabilities': array([0.00113305, 0.00152563, 0.5085974 , 0.4618619 , 0.02688213],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-4.860078  , -9.229608  ,  0.22244129,  6.508055  ,  1.1482124 ],
#       dtype=float32), 'probabilities': array([1.1482480e-05, 1.4533595e-07, 1.8507420e-03, 9.9346679e-01,
#        4.6709282e-03], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 1.1532136,  2.0878553, -1.0756325, -3.8807335, -0.3800695],
#       dtype=float32), 'probabilities': array([0.25797847, 0.6568908 , 0.02777204, 0.00168023, 0.05567844],
#       dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object)}
# {'logits': array([ 2.0220098,  2.3593378,  2.2514794, -3.4251885, -3.625121 ],
#       dtype=float32), 'probabilities': array([0.27270496, 0.38211375, 0.3430444 , 0.00117491, 0.000962  ],
#       dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object)}
# {'logits': array([ -6.639452 , -10.723378 ,  -0.6005546,   5.575354 ,   2.4333699],
#       dtype=float32), 'probabilities': array([4.7418116e-06, 7.9857784e-08, 1.9888587e-03, 9.5668060e-01,
#        4.1325729e-02], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 2.7555175,  3.6308682,  1.6611164, -5.042809 , -3.5013306],
#       dtype=float32), 'probabilities': array([2.6760978e-01, 6.4218765e-01, 8.9579701e-02, 1.0983271e-04,
#        5.1308266e-04], dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object)}
# {'logits': array([ 0.24063975,  0.8550007 ,  0.20115006, -3.9099178 , -1.6818526 ],
#       dtype=float32), 'probabilities': array([0.251778  , 0.46540532, 0.24202912, 0.00396692, 0.03682052],
#       dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object)}
# {'logits': array([ 3.0398552,  3.8087528, -0.097563 , -5.8764777, -2.5211213],
#       dtype=float32), 'probabilities': array([3.1203580e-01, 6.7318183e-01, 1.3540696e-02, 4.1868781e-05,
#        1.1997839e-03], dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-1.9266605,  0.4811837,  2.4096673, -1.0651764, -1.4828827],
#       dtype=float32), 'probabilities': array([0.0108153 , 0.12015782, 0.8265741 , 0.02559626, 0.01685655],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-2.5216036 , -0.1514681 ,  3.2202802 , -0.08413589, -1.6962122 ],
#       dtype=float32), 'probabilities': array([0.00296668, 0.0317401 , 0.92457014, 0.03395081, 0.00677227],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-4.2216206, -4.5695667,  2.4591515,  2.706419 ,  1.2793999],
#       dtype=float32), 'probabilities': array([4.84478893e-04, 3.42108426e-04, 3.86097789e-01, 4.94406551e-01,
#        1.18669115e-01], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-6.44992   , -7.36817   ,  1.8571159 ,  4.976183  ,  0.09519696],
#       dtype=float32), 'probabilities': array([1.0369833e-05, 4.1398175e-06, 4.2021528e-02, 9.5074815e-01,
#        7.2157271e-03], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-6.053165 , -7.13146  ,  2.9337113,  1.6166617,  1.2872188],
#       dtype=float32), 'probabilities': array([8.5595981e-05, 2.9117620e-05, 6.8454850e-01, 1.8340738e-01,
#        1.3192941e-01], dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# ...
# {'logits': array([  4.73648  , -10.088855 ,  -2.2204213,  -5.057396 ,  10.683308 ],
#       dtype=float32), 'probabilities': array([2.6072983e-03, 9.4979336e-10, 2.4822584e-06, 1.4546694e-07,
#        9.9739009e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-2.9409318, -4.1184697,  2.2058427,  3.4119563, -1.240976 ],
#       dtype=float32), 'probabilities': array([1.3283626e-03, 4.0918376e-04, 2.2831394e-01, 7.6267743e-01,
#        7.2710663e-03], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-0.4347811,  1.3897786,  1.3153679, -2.1568513, -1.438436 ],
#       dtype=float32), 'probabilities': array([0.07406992, 0.45923823, 0.42630643, 0.01323598, 0.02714939],
#       dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-3.5708902 , -3.4037783 ,  2.7179751 ,  2.7085705 , -0.03735161],
#       dtype=float32), 'probabilities': array([0.00090214, 0.00106623, 0.48584276, 0.48129502, 0.03089389],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-1.750958  , -8.510049  , -0.39962217,  4.840659  ,  1.457943  ],
#       dtype=float32), 'probabilities': array([1.3182624e-03, 1.5295582e-06, 5.0918977e-03, 9.6095890e-01,
#        3.2629456e-02], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([  7.7685533, -12.459599 ,  -7.559739 ,  -5.992348 ,  15.53266  ],
#       dtype=float32), 'probabilities': array([4.2452870e-04, 6.9651804e-13, 9.3522017e-11, 4.4835674e-10,
#        9.9957544e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-1.9504416, -4.3804836,  1.8267071,  4.5257497, -1.3173873],
#       dtype=float32), 'probabilities': array([1.4364610e-03, 1.2645626e-04, 6.2760852e-02, 9.3297088e-01,
#        2.7053659e-03], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-4.0991607 , -2.6627269 ,  3.061168  ,  1.9118885 , -0.21888125],
#       dtype=float32), 'probabilities': array([5.7179166e-04, 2.4047676e-03, 7.3608696e-01, 2.3324019e-01,
#        2.7696302e-02], dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-3.0683763 , -3.2472632 ,  0.22819856,  0.6361871 , -0.5342387 ],
#       dtype=float32), 'probabilities': array([0.01218116, 0.01018589, 0.3291341 , 0.49494857, 0.15355028],
#       dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 2.511672  ,  2.301667  , -1.8355063 , -4.6889    , -0.39270836],
#       dtype=float32), 'probabilities': array([5.3218317e-01, 4.3137711e-01, 6.8881963e-03, 3.9709319e-04,
#        2.9154444e-02], dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object)}
# {'logits': array([ 13.251901, -12.488373,  -8.283687,  -8.261578,  18.961536],
#       dtype=float32), 'probabilities': array([3.3029339e-03, 2.1879689e-14, 1.4659284e-12, 1.4987009e-12,
#        9.9669707e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 3.2065187,  3.1196687, -1.9818643, -5.501106 , -0.8546387],
#       dtype=float32), 'probabilities': array([5.1551968e-01, 4.7263601e-01, 2.8771276e-03, 8.5225984e-05,
#        8.8819237e-03], dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-2.4112105, -5.643958 ,  1.6603199,  3.1416388,  2.0540056],
#       dtype=float32), 'probabilities': array([2.4715923e-03, 9.7501754e-05, 1.4495061e-01, 6.3760048e-01,
#        2.1487978e-01], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 0.6474314,  3.6381795,  2.6339061, -4.2195344, -3.6805055],
#       dtype=float32), 'probabilities': array([3.5446856e-02, 7.0541251e-01, 2.5840014e-01, 2.7282329e-04,
#        4.6771209e-04], dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-2.5693731, -2.714337 ,  1.6993138, -0.5650283, -1.8727944],
#       dtype=float32), 'probabilities': array([0.01208884, 0.01045749, 0.86347884, 0.08971404, 0.02426078],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 0.4718987, -3.9941027,  2.6720383,  5.954184 , -2.8244748],
#       dtype=float32), 'probabilities': array([3.9924895e-03, 4.5886398e-05, 3.6037307e-02, 9.5977652e-01,
#        1.4779068e-04], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-2.8675783, -4.261589 ,  2.3375685,  3.1877775,  0.5179081],
#       dtype=float32), 'probabilities': array([1.5640181e-03, 3.8799905e-04, 2.8497607e-01, 6.6688275e-01,
#        4.6189144e-02], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-1.454983 , -7.5180244, -0.9429034,  3.6850739,  1.8555307],
#       dtype=float32), 'probabilities': array([4.9801860e-03, 1.1590442e-05, 8.3107222e-03, 8.5024440e-01,
#        1.3645306e-01], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 2.01974   ,  1.5806272 , -0.80372787, -4.639322  , -1.1985115 ],
#       dtype=float32), 'probabilities': array([0.57296246, 0.3693362 , 0.03403373, 0.00073474, 0.02293281],
#       dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-6.5579324, -2.6883707,  7.6821237,  7.404837 , -4.4943047],
#       dtype=float32), 'probabilities': array([3.7207835e-07, 1.7830500e-05, 5.6886888e-01, 4.3111005e-01,
#        2.9299267e-06], dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-2.753572  , -0.33814317,  3.0157793 , -0.27227795, -1.394666  ],
#       dtype=float32), 'probabilities': array([0.00287049, 0.03213385, 0.91950226, 0.03432161, 0.01117174],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 8.696336 , -8.255844 , -5.8571167, -4.865533 , 12.025066 ],
#       dtype=float32), 'probabilities': array([3.4598604e-02, 1.5025204e-09, 1.6541485e-08, 4.4587619e-08,
#        9.6540135e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-2.2709558, -1.828187 ,  1.4784389, -1.6171933, -1.1341271],
#       dtype=float32), 'probabilities': array([0.01996327, 0.03108306, 0.8483462 , 0.03838461, 0.06222288],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-3.1229992 , -3.6804261 ,  2.53997   ,  3.0479026 ,  0.04292262],
#       dtype=float32), 'probabilities': array([0.00126278, 0.00072317, 0.36368394, 0.6043889 , 0.02994127],
#       dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([  2.6888826, -11.257205 ,  -4.1149573,  -2.4809542,  11.968571 ],
#       dtype=float32), 'probabilities': array([9.32914700e-05, 8.18714679e-11, 1.03507425e-07, 5.30408272e-07,
#        9.99906063e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-4.330713  , -7.595985  ,  1.2387985 ,  5.136332  , -0.02915627],
#       dtype=float32), 'probabilities': array([7.5393240e-05, 2.8790071e-06, 1.9776091e-02, 9.7458047e-01,
#        5.5651213e-03], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-0.95138234, -4.2364216 ,  3.2632089 ,  5.4168367 , -2.9575086 ],
#       dtype=float32), 'probabilities': array([1.5340791e-03, 5.7434554e-05, 1.0380574e-01, 8.9439648e-01,
#        2.0634689e-04], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-2.7144792, -7.8415356, -0.0624353,  3.8439765,  1.6469679],
#       dtype=float32), 'probabilities': array([1.2519703e-03, 7.4291897e-06, 1.7756687e-02, 8.8286650e-01,
#        9.8117463e-02], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 2.5948703 ,  2.5541327 , -2.1011221 , -4.9091144 , -0.15702677],
#       dtype=float32), 'probabilities': array([4.9174598e-01, 4.7211596e-01, 4.4905255e-03, 2.7089549e-04,
#        3.1376686e-02], dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-2.5706022, -6.064544 ,  0.9527073,  1.8804351,  4.4911833],
#       dtype=float32), 'probabilities': array([7.7689876e-04, 2.3602879e-05, 2.6334094e-02, 6.6592515e-02,
#        9.0627289e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-4.2216206, -4.5695667,  2.4591515,  2.706419 ,  1.2793999],
#       dtype=float32), 'probabilities': array([4.84478893e-04, 3.42108426e-04, 3.86097789e-01, 4.94406551e-01,
#        1.18669115e-01], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-1.2545892,  0.9847693,  1.6775727, -1.7656819, -1.280187 ],
#       dtype=float32), 'probabilities': array([0.03254145, 0.3054766 , 0.6107432 , 0.01951966, 0.03171903],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 14.23422 , -12.79946 ,  -8.571781,  -8.768502,  19.859339],
#       dtype=float32), 'probabilities': array([3.5931759e-03, 6.5298147e-15, 4.4767022e-13, 3.6772479e-13,
#        9.9640685e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([  0.89505273, -10.37022   ,  -4.7688727 ,  -2.3743696 ,
#          9.871063  ], dtype=float32), 'probabilities': array([1.2638952e-04, 1.6190682e-09, 4.3842897e-07, 4.8063889e-06,
#        9.9986839e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ -8.117503  , -10.723795  ,  -0.55142736,   5.3828597 ,
#          2.871263  ], dtype=float32), 'probabilities': array([1.2645123e-06, 9.3330698e-08, 2.4424621e-03, 9.2269033e-01,
#        7.4865781e-02], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-6.145936  , -6.582829  ,  3.682731  ,  1.13751   , -0.09906554],
#       dtype=float32), 'probabilities': array([4.8926973e-05, 3.1608794e-05, 9.0799630e-01, 7.1237504e-02,
#        2.0685727e-02], dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 4.9531236,  5.262167 ,  2.48065  , -5.2548766, -4.9758224],
#       dtype=float32), 'probabilities': array([4.0873331e-01, 5.5674446e-01, 3.4487236e-02, 1.5071681e-05,
#        1.9922947e-05], dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-2.5614512,  0.4375941,  2.7370284, -1.1188712, -1.5036138],
#       dtype=float32), 'probabilities': array([0.00438192, 0.0879292 , 0.8765259 , 0.01854252, 0.01262052],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 3.1571298,  2.4406643, -1.8382298, -5.1318536, -0.7123711],
#       dtype=float32), 'probabilities': array([6.5947175e-01, 3.2213596e-01, 4.4641537e-03, 1.6570532e-04,
#        1.3762373e-02], dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object)}
# {'logits': array([ -5.7195916, -10.587322 ,  -0.6316427,   4.8530755,   2.8254855],
#       dtype=float32), 'probabilities': array([2.2544284e-05, 1.7338363e-07, 3.6534613e-03, 8.8041496e-01,
#        1.1590876e-01], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-3.2544682 , -0.31004363,  3.1973917 ,  0.21318242, -1.4869785 ],
#       dtype=float32), 'probabilities': array([0.00144551, 0.0274643 , 0.91628015, 0.04634497, 0.0084651 ],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 0.06292883, -7.025876  ,  0.41462228,  2.798831  ,  3.7187314 ],
#       dtype=float32), 'probabilities': array([1.7685179e-02, 1.4756399e-05, 2.5138997e-02, 2.7277002e-01,
#        6.8439102e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([  5.168515 , -11.948243 ,  -6.7356615,  -4.8084464,  13.449091 ],
#       dtype=float32), 'probabilities': array([2.5332707e-04, 9.3318435e-12, 1.7130218e-09, 1.1769067e-08,
#        9.9974662e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ -6.088656 , -11.612801 ,  -1.1532053,   5.5399523,   3.2548742],
#       dtype=float32), 'probabilities': array([8.0756627e-06, 3.2216125e-08, 1.1236146e-03, 9.0660644e-01,
#        9.2261814e-02], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 1.8156806,  2.449106 , -1.5815169, -4.3849416, -0.3611961],
#       dtype=float32), 'probabilities': array([0.32971272, 0.62119627, 0.01103447, 0.00066871, 0.03738782],
#       dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object)}
# {'logits': array([ 1.3071214 ,  2.1874714 , -1.1457765 , -3.9876428 , -0.42217118],
#       dtype=float32), 'probabilities': array([0.27172324, 0.6553268 , 0.02338012, 0.00136345, 0.04820639],
#       dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-2.6071286 , -0.65051913,  3.128345  ,  0.54782325, -1.5328486 ],
#       dtype=float32), 'probabilities': array([0.00290601, 0.02056087, 0.8998732 , 0.06815142, 0.00850845],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 2.739525  ,  2.1675186 , -2.432772  , -5.1753044 ,  0.18249297],
#       dtype=float32), 'probabilities': array([6.0680968e-01, 3.4247842e-01, 3.4415370e-03, 2.2165923e-04,
#        4.7048692e-02], dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object)}
# {'logits': array([ 0.4718987, -3.9941027,  2.6720383,  5.954184 , -2.8244748],
#       dtype=float32), 'probabilities': array([3.9924895e-03, 4.5886398e-05, 3.6037307e-02, 9.5977652e-01,
#        1.4779068e-04], dtype=float32), 'class_ids': array([3], dtype=int64), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-0.987589 , -0.7646933,  1.5165137,  0.3111486, -2.219563 ],
#       dtype=float32), 'probabilities': array([0.0542339 , 0.06777556, 0.6634204 , 0.1987492 , 0.0158209 ],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 2.5507329,  3.6780102,  2.4302385, -4.757503 , -4.071597 ],
#       dtype=float32), 'probabilities': array([2.0097584e-01, 6.2046057e-01, 1.7816147e-01, 1.3465337e-04,
#        2.6736379e-04], dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object)}
# {'logits': array([ 0.6158209 ,  0.27821743,  0.8769859 , -3.2743597 , -2.4875555 ],
#       dtype=float32), 'probabilities': array([0.32496452, 0.2318551 , 0.42194754, 0.00664281, 0.01459005],
#       dtype=float32), 'class_ids': array([2], dtype=int64), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-1.2666327 , -8.36466   ,  0.16994056,  2.745716  ,  5.44993   ],
#       dtype=float32), 'probabilities': array([1.1280862e-03, 9.3262702e-07, 4.7450196e-03, 6.2356699e-02,
#        9.3176931e-01], dtype=float32), 'class_ids': array([4], dtype=int64), 'classes': array([b'4'], dtype=object)}

# %%
items
# Out:
# {'class_ids': array([4], dtype=int64),
#  'classes': array([b'4'], dtype=object),
#  'logits': array([-1.2666327 , -8.36466   ,  0.16994056,  2.745716  ,  5.44993   ],
#        dtype=float32),
#  'probabilities': array([1.1280862e-03, 9.3262702e-07, 4.7450196e-03, 6.2356699e-02,
#         9.3176931e-01], dtype=float32)}

# %%
df_test.head()
# Out:
#       A_State  Hour  Minute  IsoWeekday
# 453         1    17      30           5
# 1460        3     6      15           2
# 2446        0    13      15           5
# 1323        2    20       0           7
# 475         4    23       0           5
